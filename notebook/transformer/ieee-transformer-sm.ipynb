# %% [markdown]
# # Transformer
#
# Train Base ViT model for IEEE EEG dataset

# %%
# Mount Google Drive for Colab env
import sys
from google.colab import drive

drive.mount("/content/drive", force_remount=False)
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from utils import (
    ignore_warnings,
    fix_random_seed,
    device,
    clear_cache,
    join_drive_path,
    log_json,
    train_with_kfold,
    WarmupScheduler,
    evaluate,
    Config,
    IEEEDataConfig,
    EEGDataset,
)
from models.transformer import TransformerConfig, ViTransformer

ignore_warnings()
fix_random_seed(42)
device = device(force_cuda=True)
print("Device:", device)
# Out:
# Device: cuda

# %%
config = Config(
    name="ieee transformer sm",
    batch=8,
    epochs=50,
    lr=1e-3,
    enable_fp16=True,
    grad_step=4,
    warmup_steps=30,
    lr_decay_factor=0.5,
    weight_decay=1e-3,
    patience=30,
)
config.add(k_folds=5)
data_config = IEEEDataConfig()
model_config = TransformerConfig(
    embed_dim=32,
    num_heads=4,
    num_blocks=4,
    block_hidden_dim=64,
    fc_hidden_dim=16,
    dropout=0.1,
)

print("ID:", config.id)
print("Name:", config.name)
# Out:
# ID: 250303012806180100
# Name: ieee-transformer-sm

# %%
train_data_path = join_drive_path("data", data_config.train)
val_data_path = join_drive_path("data", data_config.val)

train_data = torch.load(train_data_path, weights_only=True)
val_data = torch.load(val_data_path, weights_only=True)

# Concat Train-set and Validation-set for Cross validation
signals = torch.cat([train_data["data"], val_data["data"]], dim=0)
labels = torch.cat([train_data["label"], val_data["label"]], dim=0)

train_dataset = EEGDataset({"data": signals, "label": labels})

# %%
model_param = {
    "input_channel": data_config.channels,
    "seq_length": data_config.length,
    "embed_dim": model_config.embed_dim,
    "num_heads": model_config.num_heads,
    "num_blocks": model_config.num_blocks,
    "block_hidden_dim": model_config.block_hidden_dim,
    "fc_hidden_dim": model_config.fc_hidden_dim,
    "num_classes": data_config.num_classes,
    "dropout_p": model_config.dropout,
}

criterion = nn.CrossEntropyLoss()
check_point, best_model_path = train_with_kfold(
    k_folds=config.k_folds,
    model_class=ViTransformer,
    device=device,
    model_path=join_drive_path("log", config.model_path),
    optimizer_class=optim.Adam,
    criterion=criterion,
    epochs=config.epochs,
    train_dataset=train_dataset,
    batch=config.batch,
    gradient_step=config.grad_step,
    patience=config.patience,
    model_params=model_param,
    optimizer_params={"lr": config.lr, "weight_decay": config.weight_decay},
    enable_fp16=config.enable_fp16,
    scheduler_class=WarmupScheduler,
    scheduler_params={
        "lr": config.lr,
        "warmup_steps": config.warmup_steps,
        "decay_factor": config.lr_decay_factor,
    },
)
# Out:
# ===== Fold 1 =====
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1, Train-Loss: 0.70930,  Val-Loss: 0.61891
# Epoch 2, Train-Loss: 0.74221,  Val-Loss: 0.62191
# Epoch 3, Train-Loss: 0.71575,  Val-Loss: 0.62577
# Epoch 4, Train-Loss: 0.68658,  Val-Loss: 0.63199
# Epoch 5, Train-Loss: 0.70477,  Val-Loss: 0.63704
# Epoch 6, Train-Loss: 0.68911,  Val-Loss: 0.64607
# Epoch 7, Train-Loss: 0.69961,  Val-Loss: 0.65375
# Epoch 8, Train-Loss: 0.66531,  Val-Loss: 0.66093
# Epoch 9, Train-Loss: 0.67174,  Val-Loss: 0.66049
# Epoch 10, Train-Loss: 0.65581,  Val-Loss: 0.65605
# Epoch 11, Train-Loss: 0.64386,  Val-Loss: 0.65476
# Epoch 12, Train-Loss: 0.66868,  Val-Loss: 0.64147
# Epoch 13, Train-Loss: 0.63774,  Val-Loss: 0.63545
# Epoch 14, Train-Loss: 0.64486,  Val-Loss: 0.63030
# Epoch 15, Train-Loss: 0.63013,  Val-Loss: 0.61938
# Epoch 16, Train-Loss: 0.63768,  Val-Loss: 0.60935
# Epoch 17, Train-Loss: 0.63651,  Val-Loss: 0.60205
# Epoch 18, Train-Loss: 0.60311,  Val-Loss: 0.60168
# Epoch 19, Train-Loss: 0.59671,  Val-Loss: 0.61282
# Epoch 20, Train-Loss: 0.58090,  Val-Loss: 0.59736
# Epoch 21, Train-Loss: 0.56981,  Val-Loss: 0.58196
# Epoch 22, Train-Loss: 0.55447,  Val-Loss: 0.58394
# Epoch 23, Train-Loss: 0.53017,  Val-Loss: 0.58061
# Epoch 24, Train-Loss: 0.49534,  Val-Loss: 0.56953
# Epoch 25, Train-Loss: 0.51152,  Val-Loss: 0.56073
# Epoch 26, Train-Loss: 0.48921,  Val-Loss: 0.55077
# Epoch 27, Train-Loss: 0.48991,  Val-Loss: 0.53807
# Epoch 28, Train-Loss: 0.47777,  Val-Loss: 0.52073
# Epoch 29, Train-Loss: 0.43535,  Val-Loss: 0.50874
# Epoch 30, Train-Loss: 0.42369,  Val-Loss: 0.49944
# Epoch 31, Train-Loss: 0.38960,  Val-Loss: 0.49709
# Epoch 32, Train-Loss: 0.37967,  Val-Loss: 0.54487
# Epoch 33, Train-Loss: 0.39021,  Val-Loss: 0.48939
# Epoch 34, Train-Loss: 0.36631,  Val-Loss: 0.45261
# Epoch 35, Train-Loss: 0.36952,  Val-Loss: 0.44611
# Epoch 36, Train-Loss: 0.32487,  Val-Loss: 0.45832
# Epoch 37, Train-Loss: 0.32348,  Val-Loss: 0.46618
# Epoch 38, Train-Loss: 0.32874,  Val-Loss: 0.46383
# Epoch 39, Train-Loss: 0.34783,  Val-Loss: 0.46331
# Epoch 40, Train-Loss: 0.30990,  Val-Loss: 0.46171
# Epoch 41, Train-Loss: 0.31422,  Val-Loss: 0.46074
# Epoch 42, Train-Loss: 0.34084,  Val-Loss: 0.46001
# Epoch 43, Train-Loss: 0.34772,  Val-Loss: 0.45970
# Epoch 44, Train-Loss: 0.28500,  Val-Loss: 0.45956
# Epoch 45, Train-Loss: 0.33110,  Val-Loss: 0.45952
# Epoch 46, Train-Loss: 0.32153,  Val-Loss: 0.45948
# Epoch 47, Train-Loss: 0.32255,  Val-Loss: 0.45944
# Epoch 48, Train-Loss: 0.29868,  Val-Loss: 0.45940
# Epoch 49, Train-Loss: 0.33456,  Val-Loss: 0.45933
# Epoch 50, Train-Loss: 0.32976,  Val-Loss: 0.45928
#
# ===== Fold 2 =====
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1, Train-Loss: 0.79971,  Val-Loss: 0.70547
# Epoch 2, Train-Loss: 0.74759,  Val-Loss: 0.70012
# Epoch 3, Train-Loss: 0.77210,  Val-Loss: 0.69473
# Epoch 4, Train-Loss: 0.72796,  Val-Loss: 0.69169
# Epoch 5, Train-Loss: 0.71608,  Val-Loss: 0.69278
# Epoch 6, Train-Loss: 0.69677,  Val-Loss: 0.69772
# Epoch 7, Train-Loss: 0.69807,  Val-Loss: 0.70102
# Epoch 8, Train-Loss: 0.67199,  Val-Loss: 0.70462
# Epoch 9, Train-Loss: 0.72549,  Val-Loss: 0.70513
# Epoch 10, Train-Loss: 0.66281,  Val-Loss: 0.70260
# Epoch 11, Train-Loss: 0.62716,  Val-Loss: 0.69767
# Epoch 12, Train-Loss: 0.66020,  Val-Loss: 0.68966
# Epoch 13, Train-Loss: 0.70724,  Val-Loss: 0.68184
# Epoch 14, Train-Loss: 0.63162,  Val-Loss: 0.67239
# Epoch 15, Train-Loss: 0.62857,  Val-Loss: 0.66634
# Epoch 16, Train-Loss: 0.59206,  Val-Loss: 0.65785
# Epoch 17, Train-Loss: 0.64023,  Val-Loss: 0.65037
# Epoch 18, Train-Loss: 0.59327,  Val-Loss: 0.64640
# Epoch 19, Train-Loss: 0.62196,  Val-Loss: 0.64174
# Epoch 20, Train-Loss: 0.62442,  Val-Loss: 0.63888
# Epoch 21, Train-Loss: 0.59897,  Val-Loss: 0.63544
# Epoch 22, Train-Loss: 0.59433,  Val-Loss: 0.63125
# Epoch 23, Train-Loss: 0.59803,  Val-Loss: 0.62919
# Epoch 24, Train-Loss: 0.54684,  Val-Loss: 0.62615
# Epoch 25, Train-Loss: 0.54174,  Val-Loss: 0.61533
# Epoch 26, Train-Loss: 0.52041,  Val-Loss: 0.60489
# Epoch 27, Train-Loss: 0.57630,  Val-Loss: 0.59485
# Epoch 28, Train-Loss: 0.51603,  Val-Loss: 0.59111
# Epoch 29, Train-Loss: 0.53041,  Val-Loss: 0.58672
# Epoch 30, Train-Loss: 0.48276,  Val-Loss: 0.58417
# Epoch 31, Train-Loss: 0.50480,  Val-Loss: 0.56761
# Epoch 32, Train-Loss: 0.46645,  Val-Loss: 0.55726
# Epoch 33, Train-Loss: 0.47113,  Val-Loss: 0.55023
# Epoch 34, Train-Loss: 0.43752,  Val-Loss: 0.54148
# Epoch 35, Train-Loss: 0.44997,  Val-Loss: 0.53466
# Epoch 36, Train-Loss: 0.43253,  Val-Loss: 0.52098
# Epoch 37, Train-Loss: 0.43864,  Val-Loss: 0.52058
# Epoch 38, Train-Loss: 0.39693,  Val-Loss: 0.50919
# Epoch 39, Train-Loss: 0.33605,  Val-Loss: 0.49953
# Epoch 40, Train-Loss: 0.35250,  Val-Loss: 0.48840
# Epoch 41, Train-Loss: 0.32622,  Val-Loss: 0.48226
# Epoch 42, Train-Loss: 0.34227,  Val-Loss: 0.46414
# Epoch 43, Train-Loss: 0.30464,  Val-Loss: 0.44700
# Epoch 44, Train-Loss: 0.26917,  Val-Loss: 0.43628
# Epoch 45, Train-Loss: 0.27297,  Val-Loss: 0.44357
# Epoch 46, Train-Loss: 0.25507,  Val-Loss: 0.42634
# Epoch 47, Train-Loss: 0.26505,  Val-Loss: 0.41904
# Epoch 48, Train-Loss: 0.27133,  Val-Loss: 0.40718
# Epoch 49, Train-Loss: 0.25923,  Val-Loss: 0.39991
# Epoch 50, Train-Loss: 0.26248,  Val-Loss: 0.40219
#
# ===== Fold 3 =====
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1, Train-Loss: 0.80287,  Val-Loss: 0.77357
# Epoch 2, Train-Loss: 0.78662,  Val-Loss: 0.75573
# Epoch 3, Train-Loss: 0.79580,  Val-Loss: 0.73220
# Epoch 4, Train-Loss: 0.73017,  Val-Loss: 0.70623
# Epoch 5, Train-Loss: 0.71905,  Val-Loss: 0.68281
# Epoch 6, Train-Loss: 0.67437,  Val-Loss: 0.66520
# Epoch 7, Train-Loss: 0.72603,  Val-Loss: 0.65591
# Epoch 8, Train-Loss: 0.69704,  Val-Loss: 0.65096
# Epoch 9, Train-Loss: 0.69152,  Val-Loss: 0.64680
# Epoch 10, Train-Loss: 0.68314,  Val-Loss: 0.64261
# Epoch 11, Train-Loss: 0.64982,  Val-Loss: 0.63811
# Epoch 12, Train-Loss: 0.67232,  Val-Loss: 0.63477
# Epoch 13, Train-Loss: 0.64902,  Val-Loss: 0.63119
# Epoch 14, Train-Loss: 0.68590,  Val-Loss: 0.63009
# Epoch 15, Train-Loss: 0.62186,  Val-Loss: 0.62683
# Epoch 16, Train-Loss: 0.61387,  Val-Loss: 0.62405
# Epoch 17, Train-Loss: 0.62640,  Val-Loss: 0.61581
# Epoch 18, Train-Loss: 0.60097,  Val-Loss: 0.60155
# Epoch 19, Train-Loss: 0.60945,  Val-Loss: 0.59424
# Epoch 20, Train-Loss: 0.59105,  Val-Loss: 0.58655
# Epoch 21, Train-Loss: 0.56399,  Val-Loss: 0.58440
# Epoch 22, Train-Loss: 0.56259,  Val-Loss: 0.58552
# Epoch 23, Train-Loss: 0.57340,  Val-Loss: 0.57910
# Epoch 24, Train-Loss: 0.57486,  Val-Loss: 0.57127
# Epoch 25, Train-Loss: 0.55526,  Val-Loss: 0.56132
# Epoch 26, Train-Loss: 0.54276,  Val-Loss: 0.55367
# Epoch 27, Train-Loss: 0.53511,  Val-Loss: 0.54788
# Epoch 28, Train-Loss: 0.51098,  Val-Loss: 0.54473
# Epoch 29, Train-Loss: 0.49225,  Val-Loss: 0.54123
# Epoch 30, Train-Loss: 0.51173,  Val-Loss: 0.53273
# Epoch 31, Train-Loss: 0.46442,  Val-Loss: 0.52773
# Epoch 32, Train-Loss: 0.47407,  Val-Loss: 0.53207
# Epoch 33, Train-Loss: 0.45385,  Val-Loss: 0.52561
# Epoch 34, Train-Loss: 0.48979,  Val-Loss: 0.51614
# Epoch 35, Train-Loss: 0.39654,  Val-Loss: 0.51393
# Epoch 36, Train-Loss: 0.44656,  Val-Loss: 0.51181
# Epoch 37, Train-Loss: 0.41241,  Val-Loss: 0.50945
# Epoch 38, Train-Loss: 0.38896,  Val-Loss: 0.50984
# Epoch 39, Train-Loss: 0.40201,  Val-Loss: 0.50785
# Epoch 40, Train-Loss: 0.43956,  Val-Loss: 0.50501
# Epoch 41, Train-Loss: 0.39398,  Val-Loss: 0.50622
# Epoch 42, Train-Loss: 0.41432,  Val-Loss: 0.50612
# Epoch 43, Train-Loss: 0.43508,  Val-Loss: 0.50522
# Epoch 44, Train-Loss: 0.37918,  Val-Loss: 0.50475
# Epoch 45, Train-Loss: 0.36771,  Val-Loss: 0.50424
# Epoch 46, Train-Loss: 0.42136,  Val-Loss: 0.50372
# Epoch 47, Train-Loss: 0.37876,  Val-Loss: 0.50292
# Epoch 48, Train-Loss: 0.37097,  Val-Loss: 0.50210
# Epoch 49, Train-Loss: 0.38531,  Val-Loss: 0.50105
# Epoch 50, Train-Loss: 0.38410,  Val-Loss: 0.50061
#
# ===== Fold 4 =====
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1, Train-Loss: 0.65219,  Val-Loss: 0.68580
# Epoch 2, Train-Loss: 0.67183,  Val-Loss: 0.68595
# Epoch 3, Train-Loss: 0.66912,  Val-Loss: 0.68602
# Epoch 4, Train-Loss: 0.67036,  Val-Loss: 0.68608
# Epoch 5, Train-Loss: 0.66525,  Val-Loss: 0.68642
# Epoch 6, Train-Loss: 0.65525,  Val-Loss: 0.68666
# Epoch 7, Train-Loss: 0.66714,  Val-Loss: 0.68708
# Epoch 8, Train-Loss: 0.65917,  Val-Loss: 0.68652
# Epoch 9, Train-Loss: 0.66055,  Val-Loss: 0.68591
# Epoch 10, Train-Loss: 0.67485,  Val-Loss: 0.68514
# Epoch 11, Train-Loss: 0.64726,  Val-Loss: 0.68439
# Epoch 12, Train-Loss: 0.63649,  Val-Loss: 0.68310
# Epoch 13, Train-Loss: 0.65423,  Val-Loss: 0.68132
# Epoch 14, Train-Loss: 0.65197,  Val-Loss: 0.68069
# Epoch 15, Train-Loss: 0.63596,  Val-Loss: 0.67921
# Epoch 16, Train-Loss: 0.63409,  Val-Loss: 0.67790
# Epoch 17, Train-Loss: 0.62535,  Val-Loss: 0.67677
# Epoch 18, Train-Loss: 0.62106,  Val-Loss: 0.67483
# Epoch 19, Train-Loss: 0.62768,  Val-Loss: 0.67410
# Epoch 20, Train-Loss: 0.59466,  Val-Loss: 0.67326
# Epoch 21, Train-Loss: 0.60309,  Val-Loss: 0.67149
# Epoch 22, Train-Loss: 0.58528,  Val-Loss: 0.66870
# Epoch 23, Train-Loss: 0.58245,  Val-Loss: 0.66801
# Epoch 24, Train-Loss: 0.59277,  Val-Loss: 0.66420
# Epoch 25, Train-Loss: 0.57560,  Val-Loss: 0.66352
# Epoch 26, Train-Loss: 0.55982,  Val-Loss: 0.66077
# Epoch 27, Train-Loss: 0.54139,  Val-Loss: 0.65383
# Epoch 28, Train-Loss: 0.52465,  Val-Loss: 0.64318
# Epoch 29, Train-Loss: 0.51232,  Val-Loss: 0.63689
# Epoch 30, Train-Loss: 0.50471,  Val-Loss: 0.62960
# Epoch 31, Train-Loss: 0.48996,  Val-Loss: 0.61729
# Epoch 32, Train-Loss: 0.47009,  Val-Loss: 0.60095
# Epoch 33, Train-Loss: 0.47215,  Val-Loss: 0.58219
# Epoch 34, Train-Loss: 0.43407,  Val-Loss: 0.58151
# Epoch 35, Train-Loss: 0.41034,  Val-Loss: 0.57978
# Epoch 36, Train-Loss: 0.35664,  Val-Loss: 0.56533
# Epoch 37, Train-Loss: 0.32406,  Val-Loss: 0.57463
# Epoch 38, Train-Loss: 0.32445,  Val-Loss: 0.54775
# Epoch 39, Train-Loss: 0.31188,  Val-Loss: 0.52759
# Epoch 40, Train-Loss: 0.30730,  Val-Loss: 0.52119
# Epoch 41, Train-Loss: 0.29699,  Val-Loss: 0.52399
# Epoch 42, Train-Loss: 0.28802,  Val-Loss: 0.52316
# Epoch 43, Train-Loss: 0.26644,  Val-Loss: 0.52099
# Epoch 44, Train-Loss: 0.27485,  Val-Loss: 0.51737
# Epoch 45, Train-Loss: 0.25913,  Val-Loss: 0.51514
# Epoch 46, Train-Loss: 0.26906,  Val-Loss: 0.51642
# Epoch 47, Train-Loss: 0.26607,  Val-Loss: 0.51629
# Epoch 48, Train-Loss: 0.26638,  Val-Loss: 0.51566
# Epoch 49, Train-Loss: 0.25460,  Val-Loss: 0.51524
# Epoch 50, Train-Loss: 0.25035,  Val-Loss: 0.51523
#
# ===== Fold 5 =====
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1, Train-Loss: 0.69108,  Val-Loss: 0.76678
# Epoch 2, Train-Loss: 0.68906,  Val-Loss: 0.76171
# Epoch 3, Train-Loss: 0.67436,  Val-Loss: 0.75415
# Epoch 4, Train-Loss: 0.67359,  Val-Loss: 0.74421
# Epoch 5, Train-Loss: 0.66190,  Val-Loss: 0.73400
# Epoch 6, Train-Loss: 0.68461,  Val-Loss: 0.72246
# Epoch 7, Train-Loss: 0.66427,  Val-Loss: 0.71522
# Epoch 8, Train-Loss: 0.64807,  Val-Loss: 0.71039
# Epoch 9, Train-Loss: 0.67149,  Val-Loss: 0.70541
# Epoch 10, Train-Loss: 0.67436,  Val-Loss: 0.70140
# Epoch 11, Train-Loss: 0.65320,  Val-Loss: 0.69974
# Epoch 12, Train-Loss: 0.64071,  Val-Loss: 0.70004
# Epoch 13, Train-Loss: 0.64126,  Val-Loss: 0.69482
# Epoch 14, Train-Loss: 0.63503,  Val-Loss: 0.69197
# Epoch 15, Train-Loss: 0.64208,  Val-Loss: 0.68976
# Epoch 16, Train-Loss: 0.62703,  Val-Loss: 0.69024
# Epoch 17, Train-Loss: 0.62573,  Val-Loss: 0.69161
# Epoch 18, Train-Loss: 0.63301,  Val-Loss: 0.69373
# Epoch 19, Train-Loss: 0.61411,  Val-Loss: 0.69202
# Epoch 20, Train-Loss: 0.61457,  Val-Loss: 0.68024
# Epoch 21, Train-Loss: 0.60557,  Val-Loss: 0.66955
# Epoch 22, Train-Loss: 0.58120,  Val-Loss: 0.66311
# Epoch 23, Train-Loss: 0.58550,  Val-Loss: 0.66507
# Epoch 24, Train-Loss: 0.57285,  Val-Loss: 0.66475
# Epoch 25, Train-Loss: 0.54362,  Val-Loss: 0.64875
# Epoch 26, Train-Loss: 0.56350,  Val-Loss: 0.63867
# Epoch 27, Train-Loss: 0.53937,  Val-Loss: 0.63166
# Epoch 28, Train-Loss: 0.54945,  Val-Loss: 0.62156
# Epoch 29, Train-Loss: 0.51192,  Val-Loss: 0.60037
# Epoch 30, Train-Loss: 0.51413,  Val-Loss: 0.59860
# Epoch 31, Train-Loss: 0.49371,  Val-Loss: 0.59270
# Epoch 32, Train-Loss: 0.47469,  Val-Loss: 0.56326
# Epoch 33, Train-Loss: 0.45521,  Val-Loss: 0.58632
# Epoch 34, Train-Loss: 0.44973,  Val-Loss: 0.54910
# Epoch 35, Train-Loss: 0.42087,  Val-Loss: 0.52618
# Epoch 36, Train-Loss: 0.39647,  Val-Loss: 0.52227
# Epoch 37, Train-Loss: 0.40190,  Val-Loss: 0.51840
# Epoch 38, Train-Loss: 0.40273,  Val-Loss: 0.52260
# Epoch 39, Train-Loss: 0.37126,  Val-Loss: 0.51934
# Epoch 40, Train-Loss: 0.38396,  Val-Loss: 0.51595
# Epoch 41, Train-Loss: 0.36769,  Val-Loss: 0.51149
# Epoch 42, Train-Loss: 0.35950,  Val-Loss: 0.50780
# Epoch 43, Train-Loss: 0.38090,  Val-Loss: 0.50503
# Epoch 44, Train-Loss: 0.38843,  Val-Loss: 0.50506
# Epoch 45, Train-Loss: 0.32961,  Val-Loss: 0.50585
# Epoch 46, Train-Loss: 0.34146,  Val-Loss: 0.50585
# Epoch 47, Train-Loss: 0.37709,  Val-Loss: 0.50568
# Epoch 48, Train-Loss: 0.37044,  Val-Loss: 0.50567
# Epoch 49, Train-Loss: 0.36455,  Val-Loss: 0.50564
# Epoch 50, Train-Loss: 0.34925,  Val-Loss: 0.50553

# %%
config.epochs = check_point
config.model_path = best_model_path

print("Best model path:", join_drive_path("log", config.model_path))
print("Model checkpoint:", config.epochs)
# Out:
# Best model path: /content/drive/MyDrive/log/ieee-transformer-sm_250303012806180100_2.pt
# Model checkpoint: 49

# %%
clear_cache()

trained_weights = torch.load(
    join_drive_path("log", config.model_path), weights_only=True, map_location=device
)
model = ViTransformer(**model_param)
model.load_state_dict(trained_weights)
# Out:
# <All keys matched successfully>

# %%
test_data_path = join_drive_path("data", data_config.test)
test_dataset = EEGDataset(test_data_path)
test_dataloader = DataLoader(test_dataset, batch_size=config.batch)

metrics = evaluate(model, device, test_dataloader)

print(f"Accuracy: {metrics['accuracy']:.3f}")
print(f"F1-Score: {metrics['f1-score']:.3f}")
print(f"Recall: {metrics['recall']:.3f}")
print(f"AUC: {metrics['auc']:.3f}")
# Out:
# Accuracy: 0.944
# F1-Score: 0.952
# Recall: 0.952
# AUC: 0.943

# %%
json_path = join_drive_path("log", f"{config.name}_{config.id}.json")
log_json(
    json_path, config=config, data=data_config, model=model_config, metrics=metrics
)
# Out:
# {'config': {'name': 'ieee-transformer-sm',
#   'batch': 8,
#   'epochs': 49,
#   'lr': 0.001,
#   'enable_fp16': True,
#   'grad_step': 4,
#   'warmup_steps': 30,
#   'lr_decay_factor': 0.5,
#   'weight_decay': 0.001,
#   'patience': 30,
#   'id': '250303012806180100',
#   'model_path': '/content/drive/MyDrive/log/ieee-transformer-sm_250303012806180100_2.pt',
#   'k_folds': 5},
#  'data': {'tag': 'IEEE_23',
#   'train': 'ieee_train.pt',
#   'test': 'ieee_test.pt',
#   'val': 'ieee_val.pt',
#   'channels': 19,
#   'length': 9250,
#   'num_classes': 2},
#  'model': {'embed_dim': 32,
#   'num_heads': 4,
#   'num_blocks': 4,
#   'block_hidden_dim': 64,
#   'fc_hidden_dim': 16,
#   'dropout': 0.1},
#  'metrics': {'accuracy': 0.9444444444444444,
#   'f1-score': 0.9523809523809523,
#   'recall': 0.9523809523809523,
#   'auc': 0.9428571428571428}}
